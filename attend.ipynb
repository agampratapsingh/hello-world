# %% [markdown]
# <a href="https://colab.research.google.com/github/agampratapsingh/hello-world/blob/master/attend.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/cesc-park/attend2u
# !wget http://download.tensorflow.org/models/resnet_v1_101_2016_08_28.tar.gz
# !tar -xvf resnet_v1_101_2016_08_28.tar.gz
# !rm -rf resnet_v1_101_2016_08_28.tar.gz
# !mkdir ./attend2u/data
# !pip install colorlog
# !git clone https://github.com/circulosmeos/gdown.pl.git
# !./gdown.pl/gdown.pl 'https://drive.google.com/uc?export=download&confirm=xBSQ&id=0B3xszfcsfVUBdG0tU3BOQWV0a0E' [json.tar.gz]
# !tar -xvf /content/[json.tar.gz]
# !mv ./json ./attend2u/data
# !mv ./attend2u/scripts/generate_dataset.py /content/
# !mv ./attend2u/scripts/cnn_feature_extractor.py /content/
# !./attend2u/scripts/extract_features.sh

# %%
#!unzip ./image_info_test2014.zip -d ./image-caption-generator/Dataset/

# %%
#!git clone https://github.com/neural-nuts/image-caption-generator.git
#!pip install numpy==1.16.1
#!wget https://deepdetect.com/models/tf/inception_v4.pb
#!mv ./inception_v4.pb ./image-caption-generator/ConvNets
#!wget http://shannon.cs.illinois.edu/DenotationGraph/data/flickr30k-images.tar
#!tar -xvf ./flickr30k-images.tar
#!mkdir ./ggg
#!mkdir ./gggg
#!mv ./flickr30k-images/*.jpg ./image-caption-generator/Dataset/flickr30k-images/
#!wget http://shannon.cs.illinois.edu/DenotationGraph/data/flickr30k.tar.gz
#!tar -xvf ./flickr30k.tar.gz
#!mv ./image-caption-generator/Dataset/flickr30k-images/results_20130124.token ./image-caption-generator/Dataset/
#!cd ./image-caption-generator && python convfeatures.py --data_path Dataset/flickr30k-images/ --inception_path ConvNets/inception_v4.pb
#!cd ./image-caption-generator && python main.py --mode train --caption_path ./Dataset/results_20130124.token --feature_path ./Dataset/features.npy --resume
#!cd ./image-caption-generator && python main.py --mode test --image_path ./Images/gen_102617084.jpg
import nltk
nltk.download('punkt')

##!wget http://images.cocodataset.org/zips/test2014.zip
##!unzip test2014.zip -d ./ggg
##!mv ./gggg/annotations/image_info_test2014.json ./image-caption-generator/Dataset/COCO-images
##!wget http://images.cocodataset.org/annotations/image_info_test2014.zip
##!unzip image_info_test2014.zip -d ./gggg
##!cd ./image-caption-generator && python convfeatures.py --data_path Dataset/COCO-images/ --inception_path ConvNets/inception_v4.pb
##!cd ./image-caption-generator && python main.py --mode train --caption_path ./Dataset/image_info_test2014.json --feature_path ./Dataset/features.npy --data_is_coco --resume

#!cd ./image-caption-generator && python main.py --mode test --image_path ./Images/gen_4013421575.jpg

#!cd ./image-caption-generator && python convfeatures.py --data_path Dataset/flickr30k-images/ --inception_path ConvNets/inception_v4.pb
#!cd ./image-caption-generator && python main.py --mode train --caption_path ./Dataset/results_20130124.token --feature_path ./Dataset/features.npy --resume
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Required Files not present. Regenerating Data.
# Loading Caption Data ./Dataset/results_20130124.token
# Preprocessing Captions
# Features Loaded ./Dataset/features.npy
# (158900, 1536) (158915, 2)
# Padding Caption <PAD> to Max Length 20 + 2 for <S> and </S>
# /content/image-caption-generator/utils/data_util.py:112: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   dfPadded.set_value(i, 'caption', cap + " " + pad_buf)
# Generating Vocabulary
# Generating Word to Index and Index to Word
# Size of Vocabulary 12233
# Preprocessing Complete
# ...

# %%
#!git clone https://github.com/neural-nuts/image-caption-generator.git
#!pip install numpy==1.16.1
#!wget https://deepdetect.com/models/tf/inception_v4.pb
#!mv ./inception_v4.pb ./image-caption-generator/ConvNets
#!wget http://shannon.cs.illinois.edu/DenotationGraph/data/flickr30k-images.tar
#!tar -xvf ./flickr30k-images.tar
#!mkdir ./ggg
#!mkdir ./gggg
#mv ./flickr30k-images/*.jpg ./image-caption-generator/Dataset/flickr30k-images/
#!wget http://shannon.cs.illinois.edu/DenotationGraph/data/flickr30k.tar.gz
#!tar -xvf ./flickr30k.tar.gz
#mv ./flickr30k/results_20130124.token ./image-caption-generator/Dataset/
#!cd ./image-caption-generator && python convfeatures.py --data_path Dataset/flickr30k-images/ --inception_path ConvNets/inception_v4.pb
#import nltk
#nltk.download('punkt')
#!cd ./image-caption-generator && python main.py --mode train --caption_path ./Dataset/results_20130124.token --feature_path ./Dataset/features.npy --resume
# !cd ./image-caption-generator && python main.py --mode test --image_path ./Images/gen_7125476937.jpg
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1009 08:49:22.407546 140134617962368 module_wrapper.py:137] From /content/image-caption-generator/caption_generator.py:116: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# W1009 08:49:22.438692 140134617962368 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W1009 08:49:22.912009 140134617962368 deprecation.py:323] From /content/image-caption-generator/caption_generator.py:152: __init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
#!rm -R ./bottom-up-attention
# !cp -R ./image-caption-generator/model ./sample_data
#!cd ./image-caption-generator/Dataset && pwd && ls

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
